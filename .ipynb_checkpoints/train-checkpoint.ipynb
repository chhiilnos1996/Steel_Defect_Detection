# %% [markdown]
# # Project D - Severstal Steel Defect Detection Kaggle Competition
# ## Semantic Segmentation of steel defects
# ### Authors: Utkrisht Rajkumar, Subrato Chakravorty, Chi-Hsin Lo
#
# This is the file used to train and benchmark each of the different models we trained and tested using Keras. The models we tested are
# 1. Original U-Net with 8 starting filters instead of 64 &rarr; **UNet**
# 2. U-Net with ResNet encoder + multi-scale context aggregation with dilated convolutions (MCAD) &rarr; **UNet_Res**
# 3. Modified DeepLabv3+ with mobilenet backbone with **alpha=0.5** &rarr; **deeplabv3**
# 4. U-Net with Inverted ResNet encoder (inspired by deeplab) + MCAD &rarr; **UNet_InvRes**
#
# Note: To use DeepLabv3+, change instances of keras to tf.keras.

# %%
import os
import json
import gc
import cv2
import keras
from keras import backend as K
from keras import layers
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Model, load_model
from keras.layers import concatenate, Input
from keras.layers import *
from keras.optimizers import Adam
from keras.callbacks import Callback, ModelCheckpoint
import tensorflow as tf
import matplotlib.pyplot as plt
from keras.utils import multi_gpu_model
import numpy as np
import pandas as pd
from tqdm import tqdm
import sys
from utils import dice_coef, bce_dice, post_process
from data_gen import DataGenerator

# %%
root_dir = '../input/'

# %% [markdown]
# ### Create folders for: (1) training loss/accuracy history, (2) trained model, (3) submission.csv for Kaggle

# %%
if(os.path.exists(('./submissions'))):
      pass
else:
    os.mkdir('./submissions')

if(os.path.exists(('./history'))):
    pass
else:
    os.mkdir('./history')

if(os.path.exists(('./models'))):
      pass
else:
    os.mkdir('./models')

# %% [markdown]
# ### Load all models
#
# Loss and accuracy metrics defined in `utils.py`. `post_process()` also defined in utils.py. `post_process()` simply removes connected components that are smaller than some given size threshold.

# %%
from model import UNet, Deeplabv3
unet = UNet((256, 1600, 1))
unet_res = UNet((256, 1600, 1), MCAD=True, res_encoder=True)
unet_invres = UNet((256, 1600, 1), inv_res = True, MCAD=True)
#deeplabv1 = Deeplabv3(input_shape=(256, 1600, 1), alpha =0.5, classes=4)

# %%
unet.compile(optimizer='adam', loss=bce_dice, metrics=[dice_coef])
unet.summary()
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.7/site-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /opt/conda/lib/python3.7/site-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            (None, 256, 1600, 1) 0
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, 256, 1600, 8) 80          input_5[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, 256, 1600, 8) 584         conv2d_79[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_16 (MaxPooling2D) (None, 128, 800, 8)  0           conv2d_80[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, 128, 800, 16) 1168        max_pooling2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, 128, 800, 16) 2320        conv2d_81[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_17 (MaxPooling2D) (None, 64, 400, 16)  0           conv2d_82[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, 64, 400, 32)  4640        max_pooling2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, 64, 400, 32)  9248        conv2d_83[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_18 (MaxPooling2D) (None, 32, 200, 32)  0           conv2d_84[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 32, 200, 64)  18496       max_pooling2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, 32, 200, 64)  36928       conv2d_85[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_19 (MaxPooling2D) (None, 16, 100, 64)  0           conv2d_86[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, 16, 100, 128) 73856       max_pooling2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, 16, 100, 128) 147584      conv2d_87[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_20 (MaxPooling2D) (None, 8, 50, 128)   0           conv2d_88[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, 8, 50, 256)   295168      max_pooling2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, 8, 50, 256)   590080      conv2d_89[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_16 (Conv2DTran (None, 16, 100, 128) 131200      conv2d_90[0][0]
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, 16, 100, 256) 0           conv2d_transpose_16[0][0]
#                                                                  conv2d_88[0][0]
# __________________________________________________________________________________________________
# conv2d_91 (Conv2D)              (None, 16, 100, 128) 295040      concatenate_17[0][0]
# __________________________________________________________________________________________________
# conv2d_92 (Conv2D)              (None, 16, 100, 128) 147584      conv2d_91[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_17 (Conv2DTran (None, 32, 200, 64)  32832       conv2d_92[0][0]
# __________________________________________________________________________________________________
# concatenate_18 (Concatenate)    (None, 32, 200, 128) 0           conv2d_transpose_17[0][0]
#                                                                  conv2d_86[0][0]
# __________________________________________________________________________________________________
# conv2d_93 (Conv2D)              (None, 32, 200, 64)  73792       concatenate_18[0][0]
# __________________________________________________________________________________________________
# conv2d_94 (Conv2D)              (None, 32, 200, 64)  36928       conv2d_93[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_18 (Conv2DTran (None, 64, 400, 32)  8224        conv2d_94[0][0]
# __________________________________________________________________________________________________
# concatenate_19 (Concatenate)    (None, 64, 400, 64)  0           conv2d_transpose_18[0][0]
#                                                                  conv2d_84[0][0]
# __________________________________________________________________________________________________
# conv2d_95 (Conv2D)              (None, 64, 400, 32)  18464       concatenate_19[0][0]
# __________________________________________________________________________________________________
# conv2d_96 (Conv2D)              (None, 64, 400, 32)  9248        conv2d_95[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_19 (Conv2DTran (None, 128, 800, 16) 2064        conv2d_96[0][0]
# __________________________________________________________________________________________________
# concatenate_20 (Concatenate)    (None, 128, 800, 32) 0           conv2d_transpose_19[0][0]
#                                                                  conv2d_82[0][0]
# __________________________________________________________________________________________________
# conv2d_97 (Conv2D)              (None, 128, 800, 16) 4624        concatenate_20[0][0]
# __________________________________________________________________________________________________
# conv2d_98 (Conv2D)              (None, 128, 800, 16) 2320        conv2d_97[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_20 (Conv2DTran (None, 256, 1600, 8) 520         conv2d_98[0][0]
# __________________________________________________________________________________________________
# concatenate_21 (Concatenate)    (None, 256, 1600, 16 0           conv2d_transpose_20[0][0]
#                                                                  conv2d_80[0][0]
# __________________________________________________________________________________________________
# conv2d_99 (Conv2D)              (None, 256, 1600, 8) 1160        concatenate_21[0][0]
# __________________________________________________________________________________________________
# conv2d_100 (Conv2D)             (None, 256, 1600, 8) 584         conv2d_99[0][0]
# __________________________________________________________________________________________________
# conv2d_101 (Conv2D)             (None, 256, 1600, 4) 36          conv2d_100[0][0]
# ==================================================================================================
# Total params: 1,944,772
# Trainable params: 1,944,772
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
unet_res.compile(optimizer='adam', loss=bce_dice, metrics=[dice_coef])
unet_res.summary()
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_6 (InputLayer)            (None, 256, 1600, 1) 0
# __________________________________________________________________________________________________
# conv2d_102 (Conv2D)             (None, 256, 1600, 8) 80          input_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 256, 1600, 8) 32          conv2d_102[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)      (None, 256, 1600, 8) 0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv2d_103 (Conv2D)             (None, 256, 1600, 8) 584         leaky_re_lu_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 256, 1600, 8) 32          conv2d_103[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 256, 1600, 8) 0           batch_normalization_34[0][0]
#                                                                  input_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)      (None, 256, 1600, 8) 0           add_12[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_21 (MaxPooling2D) (None, 128, 800, 8)  0           leaky_re_lu_14[0][0]
# __________________________________________________________________________________________________
# conv2d_104 (Conv2D)             (None, 128, 800, 16) 1168        max_pooling2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 128, 800, 16) 64          conv2d_104[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)      (None, 128, 800, 16) 0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_105 (Conv2D)             (None, 128, 800, 16) 2320        leaky_re_lu_15[0][0]
# __________________________________________________________________________________________________
# conv2d_106 (Conv2D)             (None, 128, 800, 16) 1168        max_pooling2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 128, 800, 16) 64          conv2d_105[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 128, 800, 16) 64          conv2d_106[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 128, 800, 16) 0           batch_normalization_36[0][0]
#                                                                  batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)      (None, 128, 800, 16) 0           add_13[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_22 (MaxPooling2D) (None, 64, 400, 16)  0           leaky_re_lu_16[0][0]
# __________________________________________________________________________________________________
# conv2d_107 (Conv2D)             (None, 64, 400, 32)  4640        max_pooling2d_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 64, 400, 32)  128         conv2d_107[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)      (None, 64, 400, 32)  0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# conv2d_108 (Conv2D)             (None, 64, 400, 32)  9248        leaky_re_lu_17[0][0]
# __________________________________________________________________________________________________
# conv2d_109 (Conv2D)             (None, 64, 400, 32)  4640        max_pooling2d_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 64, 400, 32)  128         conv2d_108[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 64, 400, 32)  128         conv2d_109[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 64, 400, 32)  0           batch_normalization_39[0][0]
#                                                                  batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)      (None, 64, 400, 32)  0           add_14[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_23 (MaxPooling2D) (None, 32, 200, 32)  0           leaky_re_lu_18[0][0]
# __________________________________________________________________________________________________
# conv2d_110 (Conv2D)             (None, 32, 200, 64)  18496       max_pooling2d_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 32, 200, 64)  256         conv2d_110[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)      (None, 32, 200, 64)  0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv2d_111 (Conv2D)             (None, 32, 200, 64)  36928       leaky_re_lu_19[0][0]
# __________________________________________________________________________________________________
# conv2d_112 (Conv2D)             (None, 32, 200, 64)  18496       max_pooling2d_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 32, 200, 64)  256         conv2d_111[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 32, 200, 64)  256         conv2d_112[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 32, 200, 64)  0           batch_normalization_42[0][0]
#                                                                  batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)      (None, 32, 200, 64)  0           add_15[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_24 (MaxPooling2D) (None, 16, 100, 64)  0           leaky_re_lu_20[0][0]
# __________________________________________________________________________________________________
# conv2d_113 (Conv2D)             (None, 16, 100, 128) 73856       max_pooling2d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 16, 100, 128) 512         conv2d_113[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_21 (LeakyReLU)      (None, 16, 100, 128) 0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_114 (Conv2D)             (None, 16, 100, 128) 147584      leaky_re_lu_21[0][0]
# __________________________________________________________________________________________________
# conv2d_115 (Conv2D)             (None, 16, 100, 128) 73856       max_pooling2d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 16, 100, 128) 512         conv2d_114[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 16, 100, 128) 512         conv2d_115[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 16, 100, 128) 0           batch_normalization_45[0][0]
#                                                                  batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_22 (LeakyReLU)      (None, 16, 100, 128) 0           add_16[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_25 (MaxPooling2D) (None, 8, 50, 128)   0           leaky_re_lu_22[0][0]
# __________________________________________________________________________________________________
# conv2d_116 (Conv2D)             (None, 8, 50, 128)   147584      max_pooling2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_117 (Conv2D)             (None, 8, 50, 128)   147584      conv2d_116[0][0]
# __________________________________________________________________________________________________
# conv2d_118 (Conv2D)             (None, 8, 50, 128)   147584      conv2d_117[0][0]
# __________________________________________________________________________________________________
# conv2d_119 (Conv2D)             (None, 8, 50, 128)   147584      conv2d_118[0][0]
# __________________________________________________________________________________________________
# conv2d_120 (Conv2D)             (None, 8, 50, 128)   147584      conv2d_119[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 8, 50, 128)   0           conv2d_116[0][0]
#                                                                  conv2d_117[0][0]
#                                                                  conv2d_118[0][0]
#                                                                  conv2d_119[0][0]
#                                                                  conv2d_120[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_23 (LeakyReLU)      (None, 8, 50, 128)   0           add_17[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_21 (Conv2DTran (None, 16, 100, 128) 65664       leaky_re_lu_23[0][0]
# __________________________________________________________________________________________________
# concatenate_22 (Concatenate)    (None, 16, 100, 256) 0           conv2d_transpose_21[0][0]
#                                                                  leaky_re_lu_22[0][0]
# __________________________________________________________________________________________________
# conv2d_121 (Conv2D)             (None, 16, 100, 128) 295040      concatenate_22[0][0]
# __________________________________________________________________________________________________
# conv2d_122 (Conv2D)             (None, 16, 100, 128) 147584      conv2d_121[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_22 (Conv2DTran (None, 32, 200, 64)  32832       conv2d_122[0][0]
# __________________________________________________________________________________________________
# concatenate_23 (Concatenate)    (None, 32, 200, 128) 0           conv2d_transpose_22[0][0]
#                                                                  leaky_re_lu_20[0][0]
# __________________________________________________________________________________________________
# conv2d_123 (Conv2D)             (None, 32, 200, 64)  73792       concatenate_23[0][0]
# __________________________________________________________________________________________________
# conv2d_124 (Conv2D)             (None, 32, 200, 64)  36928       conv2d_123[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_23 (Conv2DTran (None, 64, 400, 32)  8224        conv2d_124[0][0]
# __________________________________________________________________________________________________
# concatenate_24 (Concatenate)    (None, 64, 400, 64)  0           conv2d_transpose_23[0][0]
#                                                                  leaky_re_lu_18[0][0]
# __________________________________________________________________________________________________
# conv2d_125 (Conv2D)             (None, 64, 400, 32)  18464       concatenate_24[0][0]
# __________________________________________________________________________________________________
# conv2d_126 (Conv2D)             (None, 64, 400, 32)  9248        conv2d_125[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_24 (Conv2DTran (None, 128, 800, 16) 2064        conv2d_126[0][0]
# __________________________________________________________________________________________________
# concatenate_25 (Concatenate)    (None, 128, 800, 32) 0           conv2d_transpose_24[0][0]
#                                                                  leaky_re_lu_16[0][0]
# __________________________________________________________________________________________________
# conv2d_127 (Conv2D)             (None, 128, 800, 16) 4624        concatenate_25[0][0]
# __________________________________________________________________________________________________
# conv2d_128 (Conv2D)             (None, 128, 800, 16) 2320        conv2d_127[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_25 (Conv2DTran (None, 256, 1600, 8) 520         conv2d_128[0][0]
# __________________________________________________________________________________________________
# concatenate_26 (Concatenate)    (None, 256, 1600, 16 0           conv2d_transpose_25[0][0]
#                                                                  leaky_re_lu_14[0][0]
# __________________________________________________________________________________________________
# conv2d_129 (Conv2D)             (None, 256, 1600, 8) 1160        concatenate_26[0][0]
# __________________________________________________________________________________________________
# conv2d_130 (Conv2D)             (None, 256, 1600, 8) 584         conv2d_129[0][0]
# __________________________________________________________________________________________________
# conv2d_131 (Conv2D)             (None, 256, 1600, 4) 36          conv2d_130[0][0]
# ==================================================================================================
# Total params: 1,833,012
# Trainable params: 1,831,540
# Non-trainable params: 1,472
# __________________________________________________________________________________________________

# %%
#deeplabv3.compile(optimizer='adam', loss=bce_dice, metrics=[dice_coef])
#deeplabv3.summary()

# %% [markdown]
# Because deeplab requires us to change the DataGenerator from keras to tf.keras, we created a separate notebook (deeplab.ipynb) for that.

# %%
unet_invres.compile(optimizer='adam', loss=bce_dice, metrics=[dice_coef])
unet_invres.summary()
# Out:
# Model: "model_6"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_7 (InputLayer)            (None, 256, 1600, 1) 0
# __________________________________________________________________________________________________
# depthwise_conv2d_10 (DepthwiseC (None, 256, 1600, 1) 9           input_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 256, 1600, 1) 4           depthwise_conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 256, 1600, 1) 0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv2d_132 (Conv2D)             (None, 256, 1600, 8) 8           activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 256, 1600, 8) 32          conv2d_132[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_26 (MaxPooling2D) (None, 128, 800, 8)  0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_11 (DepthwiseC (None, 128, 800, 8)  72          max_pooling2d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 128, 800, 8)  32          depthwise_conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 128, 800, 8)  0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# conv2d_133 (Conv2D)             (None, 128, 800, 16) 128         activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 128, 800, 16) 64          conv2d_133[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_12 (DepthwiseC (None, 128, 800, 16) 144         batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 128, 800, 16) 64          depthwise_conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 128, 800, 16) 0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# conv2d_134 (Conv2D)             (None, 128, 800, 16) 256         activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 128, 800, 16) 64          conv2d_134[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 128, 800, 16) 0           batch_normalization_50[0][0]
#                                                                  batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_27 (MaxPooling2D) (None, 64, 400, 16)  0           add_18[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_13 (DepthwiseC (None, 64, 400, 16)  144         max_pooling2d_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 64, 400, 16)  64          depthwise_conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 64, 400, 16)  0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# conv2d_135 (Conv2D)             (None, 64, 400, 32)  512         activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 64, 400, 32)  128         conv2d_135[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_14 (DepthwiseC (None, 64, 400, 32)  288         batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 64, 400, 32)  128         depthwise_conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 64, 400, 32)  0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv2d_136 (Conv2D)             (None, 64, 400, 32)  1024        activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 64, 400, 32)  128         conv2d_136[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 64, 400, 32)  0           batch_normalization_54[0][0]
#                                                                  batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_28 (MaxPooling2D) (None, 32, 200, 32)  0           add_19[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_15 (DepthwiseC (None, 32, 200, 32)  288         max_pooling2d_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 32, 200, 32)  128         depthwise_conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 32, 200, 32)  0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# conv2d_137 (Conv2D)             (None, 32, 200, 64)  2048        activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 32, 200, 64)  256         conv2d_137[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_16 (DepthwiseC (None, 32, 200, 64)  576         batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 32, 200, 64)  256         depthwise_conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 32, 200, 64)  0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# conv2d_138 (Conv2D)             (None, 32, 200, 64)  4096        activation_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 32, 200, 64)  256         conv2d_138[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, 32, 200, 64)  0           batch_normalization_58[0][0]
#                                                                  batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_29 (MaxPooling2D) (None, 16, 100, 64)  0           add_20[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_17 (DepthwiseC (None, 16, 100, 64)  576         max_pooling2d_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 16, 100, 64)  256         depthwise_conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 16, 100, 64)  0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# conv2d_139 (Conv2D)             (None, 16, 100, 128) 8192        activation_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 16, 100, 128) 512         conv2d_139[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_18 (DepthwiseC (None, 16, 100, 128) 1152        batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 16, 100, 128) 512         depthwise_conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 16, 100, 128) 0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# conv2d_140 (Conv2D)             (None, 16, 100, 128) 16384       activation_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 16, 100, 128) 512         conv2d_140[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, 16, 100, 128) 0           batch_normalization_62[0][0]
#                                                                  batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_30 (MaxPooling2D) (None, 8, 50, 128)   0           add_21[0][0]
# __________________________________________________________________________________________________
# conv2d_141 (Conv2D)             (None, 8, 50, 128)   147584      max_pooling2d_30[0][0]
# __________________________________________________________________________________________________
# conv2d_142 (Conv2D)             (None, 8, 50, 128)   147584      conv2d_141[0][0]
# __________________________________________________________________________________________________
# conv2d_143 (Conv2D)             (None, 8, 50, 128)   147584      conv2d_142[0][0]
# __________________________________________________________________________________________________
# conv2d_144 (Conv2D)             (None, 8, 50, 128)   147584      conv2d_143[0][0]
# __________________________________________________________________________________________________
# conv2d_145 (Conv2D)             (None, 8, 50, 128)   147584      conv2d_144[0][0]
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, 8, 50, 128)   0           conv2d_141[0][0]
#                                                                  conv2d_142[0][0]
#                                                                  conv2d_143[0][0]
#                                                                  conv2d_144[0][0]
#                                                                  conv2d_145[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_24 (LeakyReLU)      (None, 8, 50, 128)   0           add_22[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_26 (Conv2DTran (None, 16, 100, 128) 65664       leaky_re_lu_24[0][0]
# __________________________________________________________________________________________________
# concatenate_27 (Concatenate)    (None, 16, 100, 256) 0           conv2d_transpose_26[0][0]
#                                                                  add_21[0][0]
# __________________________________________________________________________________________________
# conv2d_146 (Conv2D)             (None, 16, 100, 128) 295040      concatenate_27[0][0]
# __________________________________________________________________________________________________
# conv2d_147 (Conv2D)             (None, 16, 100, 128) 147584      conv2d_146[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_27 (Conv2DTran (None, 32, 200, 64)  32832       conv2d_147[0][0]
# __________________________________________________________________________________________________
# concatenate_28 (Concatenate)    (None, 32, 200, 128) 0           conv2d_transpose_27[0][0]
#                                                                  add_20[0][0]
# __________________________________________________________________________________________________
# conv2d_148 (Conv2D)             (None, 32, 200, 64)  73792       concatenate_28[0][0]
# __________________________________________________________________________________________________
# conv2d_149 (Conv2D)             (None, 32, 200, 64)  36928       conv2d_148[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_28 (Conv2DTran (None, 64, 400, 32)  8224        conv2d_149[0][0]
# __________________________________________________________________________________________________
# concatenate_29 (Concatenate)    (None, 64, 400, 64)  0           conv2d_transpose_28[0][0]
#                                                                  add_19[0][0]
# __________________________________________________________________________________________________
# conv2d_150 (Conv2D)             (None, 64, 400, 32)  18464       concatenate_29[0][0]
# __________________________________________________________________________________________________
# conv2d_151 (Conv2D)             (None, 64, 400, 32)  9248        conv2d_150[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_29 (Conv2DTran (None, 128, 800, 16) 2064        conv2d_151[0][0]
# __________________________________________________________________________________________________
# concatenate_30 (Concatenate)    (None, 128, 800, 32) 0           conv2d_transpose_29[0][0]
#                                                                  add_18[0][0]
# __________________________________________________________________________________________________
# conv2d_152 (Conv2D)             (None, 128, 800, 16) 4624        concatenate_30[0][0]
# __________________________________________________________________________________________________
# conv2d_153 (Conv2D)             (None, 128, 800, 16) 2320        conv2d_152[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_30 (Conv2DTran (None, 256, 1600, 8) 520         conv2d_153[0][0]
# __________________________________________________________________________________________________
# concatenate_31 (Concatenate)    (None, 256, 1600, 16 0           conv2d_transpose_30[0][0]
#                                                                  batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# conv2d_154 (Conv2D)             (None, 256, 1600, 8) 1160        concatenate_31[0][0]
# __________________________________________________________________________________________________
# conv2d_155 (Conv2D)             (None, 256, 1600, 8) 584         conv2d_154[0][0]
# __________________________________________________________________________________________________
# conv2d_156 (Conv2D)             (None, 256, 1600, 4) 36          conv2d_155[0][0]
# ==================================================================================================
# Total params: 1,476,297
# Trainable params: 1,474,599
# Non-trainable params: 1,698
# __________________________________________________________________________________________________

# %% [markdown]
# ### Load data
#
# Remove all images with no defects at all. Only keep images with at least 1 defect. There are 4 defects total. An image can have multiple types of defects

# %%
train_path = root_dir + 'train.csv'
train_df = pd.read_csv(train_path)
train_df['ImageId'] = train_df['ImageId_ClassId'].apply(lambda x: x.split('_')[0])
train_df['ClassId'] = train_df['ImageId_ClassId'].apply(lambda x: x.split('_')[1])
train_df['hasMask'] = ~ train_df['EncodedPixels'].isna()
mask_count_df = train_df.groupby('ImageId').agg(np.sum).reset_index()
mask_count_df.sort_values('hasMask', ascending=False, inplace=True)

# %% [markdown]
# ### Create training and validation dataing. 95-5 split

# %%
BATCH_SIZE = 16

train_idx = np.load('train_idx.npy')
val_idx = np.load('val_idx.npy')

train_gen = DataGenerator(train_idx, df=mask_count_df, target_df=train_df, batch_size=BATCH_SIZE, n_classes=4)
val_gen = DataGenerator(val_idx, df=mask_count_df, target_df=train_df, batch_size=BATCH_SIZE, n_classes=4)

# %%
model_name = 'unet'
model_path = './models/' + model_name + '.h5'
chkpt = ModelCheckpoint(model_path, monitor='val_dice_coef', save_best_only=True, save_weights_only=False,mode='auto')
unet_history = unet.fit_generator(train_gen, validation_data=val_gen, callbacks=[chkpt], use_multiprocessing=False, 
                             workers=1, epochs=20)
# Out:
# Epoch 1/20
# 395/395 [==============================] - 220s 556ms/step - loss: 1.0294 - dice_coef: 0.0850 - val_loss: 0.8834 - val_dice_coef: 0.1753
# Epoch 2/20
# 395/395 [==============================] - 187s 474ms/step - loss: 0.8526 - dice_coef: 0.2048 - val_loss: 0.8392 - val_dice_coef: 0.2101
# Epoch 3/20
# 395/395 [==============================] - 178s 451ms/step - loss: 0.8397 - dice_coef: 0.2154 - val_loss: 0.8381 - val_dice_coef: 0.2188
# Epoch 4/20
# 395/395 [==============================] - 183s 463ms/step - loss: 0.8282 - dice_coef: 0.2253 - val_loss: 0.8605 - val_dice_coef: 0.1991
# Epoch 5/20
# 395/395 [==============================] - 179s 452ms/step - loss: 0.8253 - dice_coef: 0.2285 - val_loss: 0.8328 - val_dice_coef: 0.2215
# Epoch 6/20
# 395/395 [==============================] - 180s 455ms/step - loss: 0.8203 - dice_coef: 0.2322 - val_loss: 0.8051 - val_dice_coef: 0.2468
# Epoch 7/20
# 395/395 [==============================] - 183s 464ms/step - loss: 0.8147 - dice_coef: 0.2380 - val_loss: 0.7915 - val_dice_coef: 0.2529
# Epoch 8/20
# 395/395 [==============================] - 184s 465ms/step - loss: 0.8126 - dice_coef: 0.2405 - val_loss: 0.8294 - val_dice_coef: 0.2271
# Epoch 9/20
# 395/395 [==============================] - 180s 456ms/step - loss: 0.8031 - dice_coef: 0.2486 - val_loss: 0.8002 - val_dice_coef: 0.2401
# Epoch 10/20
# 395/395 [==============================] - 178s 451ms/step - loss: 0.7872 - dice_coef: 0.2637 - val_loss: 0.8344 - val_dice_coef: 0.2244
# Epoch 11/20
# 395/395 [==============================] - 183s 462ms/step - loss: 0.7622 - dice_coef: 0.2883 - val_loss: 0.7498 - val_dice_coef: 0.2969
# Epoch 12/20
# 395/395 [==============================] - 181s 457ms/step - loss: 0.6609 - dice_coef: 0.3871 - val_loss: 0.6258 - val_dice_coef: 0.4237
# Epoch 13/20
# 395/395 [==============================] - 190s 482ms/step - loss: 0.6145 - dice_coef: 0.4310 - val_loss: 0.5954 - val_dice_coef: 0.4505
# Epoch 14/20
# 395/395 [==============================] - 178s 451ms/step - loss: 0.6039 - dice_coef: 0.4420 - val_loss: 0.6173 - val_dice_coef: 0.4292
# Epoch 15/20
# 395/395 [==============================] - 178s 450ms/step - loss: 0.5769 - dice_coef: 0.4667 - val_loss: 0.5952 - val_dice_coef: 0.4498
# Epoch 16/20
# 395/395 [==============================] - 179s 453ms/step - loss: 0.5759 - dice_coef: 0.4681 - val_loss: 0.5855 - val_dice_coef: 0.4620
# Epoch 17/20
# 395/395 [==============================] - 180s 456ms/step - loss: 0.5612 - dice_coef: 0.4812 - val_loss: 0.5670 - val_dice_coef: 0.4749
# Epoch 18/20
# 395/395 [==============================] - 180s 456ms/step - loss: 0.5490 - dice_coef: 0.4933 - val_loss: 0.6095 - val_dice_coef: 0.4350
# Epoch 19/20
# 395/395 [==============================] - 180s 456ms/step - loss: 0.5471 - dice_coef: 0.4950 - val_loss: 0.5580 - val_dice_coef: 0.4813
# Epoch 20/20
# 395/395 [==============================] - 181s 459ms/step - loss: 0.5352 - dice_coef: 0.5067 - val_loss: 0.5500 - val_dice_coef: 0.4910

# %%
model_name = 'unet_res'
model_path = './models/' + model_name + '.h5'
chkpt = ModelCheckpoint(model_path, monitor='val_dice_coef', save_best_only=True, save_weights_only=False,mode='auto')
unet_res_history = unet_res.fit_generator(train_gen, validation_data=val_gen, callbacks=[chkpt], use_multiprocessing=False, 
                                          workers=1, epochs=20)
# Out:
# Epoch 1/20
# 395/395 [==============================] - 266s 673ms/step - loss: 0.9508 - dice_coef: 0.1854 - val_loss: 0.7138 - val_dice_coef: 0.3476
# Epoch 2/20
# 395/395 [==============================] - 263s 665ms/step - loss: 0.6563 - dice_coef: 0.3977 - val_loss: 0.7728 - val_dice_coef: 0.3000
# Epoch 3/20
# 395/395 [==============================] - 262s 663ms/step - loss: 0.5996 - dice_coef: 0.4461 - val_loss: 0.6091 - val_dice_coef: 0.4387
# Epoch 4/20
# 395/395 [==============================] - 264s 669ms/step - loss: 0.5821 - dice_coef: 0.4617 - val_loss: 0.6158 - val_dice_coef: 0.4405
# Epoch 5/20
# 395/395 [==============================] - 264s 669ms/step - loss: 0.5670 - dice_coef: 0.4758 - val_loss: 0.9833 - val_dice_coef: 0.1011
# Epoch 6/20
# 395/395 [==============================] - 261s 660ms/step - loss: 0.5473 - dice_coef: 0.4936 - val_loss: 0.5712 - val_dice_coef: 0.4728
# Epoch 7/20
# 395/395 [==============================] - 265s 671ms/step - loss: 0.5356 - dice_coef: 0.5047 - val_loss: 0.5336 - val_dice_coef: 0.5096
# Epoch 8/20
# 395/395 [==============================] - 267s 676ms/step - loss: 0.5298 - dice_coef: 0.5104 - val_loss: 0.5463 - val_dice_coef: 0.4971
# Epoch 9/20
# 395/395 [==============================] - 281s 711ms/step - loss: 0.5203 - dice_coef: 0.5187 - val_loss: 0.5214 - val_dice_coef: 0.5158
# Epoch 10/20
# 395/395 [==============================] - 279s 707ms/step - loss: 0.5090 - dice_coef: 0.5293 - val_loss: 0.7186 - val_dice_coef: 0.3280
# Epoch 11/20
# 395/395 [==============================] - 279s 707ms/step - loss: 0.5069 - dice_coef: 0.5309 - val_loss: 0.7014 - val_dice_coef: 0.3417
# Epoch 12/20
# 395/395 [==============================] - 280s 710ms/step - loss: 0.5030 - dice_coef: 0.5347 - val_loss: 0.5179 - val_dice_coef: 0.5271
# Epoch 13/20
# 395/395 [==============================] - 282s 715ms/step - loss: 0.4890 - dice_coef: 0.5476 - val_loss: 0.4849 - val_dice_coef: 0.5561
# Epoch 14/20
# 395/395 [==============================] - 283s 718ms/step - loss: 0.4896 - dice_coef: 0.5473 - val_loss: 0.5639 - val_dice_coef: 0.4757
# Epoch 15/20
# 395/395 [==============================] - 280s 709ms/step - loss: 0.4862 - dice_coef: 0.5502 - val_loss: 0.5841 - val_dice_coef: 0.4668
# Epoch 16/20
# 395/395 [==============================] - 282s 713ms/step - loss: 0.4816 - dice_coef: 0.5545 - val_loss: 0.5006 - val_dice_coef: 0.5362
# Epoch 17/20
# 395/395 [==============================] - 278s 705ms/step - loss: 0.4774 - dice_coef: 0.5587 - val_loss: 0.5982 - val_dice_coef: 0.4459
# Epoch 18/20
# 395/395 [==============================] - 284s 720ms/step - loss: 0.4741 - dice_coef: 0.5615 - val_loss: 0.5175 - val_dice_coef: 0.5270
# Epoch 19/20
# 395/395 [==============================] - 286s 724ms/step - loss: 0.4684 - dice_coef: 0.5665 - val_loss: 0.5038 - val_dice_coef: 0.5410
# Epoch 20/20
# 395/395 [==============================] - 279s 706ms/step - loss: 0.4688 - dice_coef: 0.5667 - val_loss: 0.4900 - val_dice_coef: 0.5505

# %%
model_name = 'unet_invres'
model_path = './models/' + model_name + '.h5'
chkpt = ModelCheckpoint(model_path, monitor='val_dice_coef', save_best_only=True, save_weights_only=False,mode='auto')
unet_invres_history = unet_invres.fit_generator(train_gen, validation_data=val_gen, callbacks=[chkpt], use_multiprocessing=False, 
                                    workers=1, epochs=20)
# Out:
# Epoch 1/20
# 395/395 [==============================] - 357s 903ms/step - loss: 0.8733 - dice_coef: 0.1972 - val_loss: 1.1179 - val_dice_coef: 0.0808
# Epoch 2/20
# 395/395 [==============================] - 344s 870ms/step - loss: 0.6404 - dice_coef: 0.4112 - val_loss: 1.0826 - val_dice_coef: 0.1449
# Epoch 3/20
# 395/395 [==============================] - 345s 873ms/step - loss: 0.5855 - dice_coef: 0.4631 - val_loss: 0.6859 - val_dice_coef: 0.3689
# Epoch 4/20
# 395/395 [==============================] - 347s 878ms/step - loss: 0.5569 - dice_coef: 0.4873 - val_loss: 0.6724 - val_dice_coef: 0.3881
# Epoch 5/20
# 395/395 [==============================] - 351s 888ms/step - loss: 0.5493 - dice_coef: 0.4942 - val_loss: 0.6989 - val_dice_coef: 0.3609
# Epoch 6/20
# 395/395 [==============================] - 348s 882ms/step - loss: 0.5248 - dice_coef: 0.5171 - val_loss: 0.6218 - val_dice_coef: 0.4331
# Epoch 7/20
# 395/395 [==============================] - 348s 880ms/step - loss: 0.5311 - dice_coef: 0.5108 - val_loss: 0.6403 - val_dice_coef: 0.4128
# Epoch 8/20
# 395/395 [==============================] - 346s 875ms/step - loss: 0.5160 - dice_coef: 0.5244 - val_loss: 0.5393 - val_dice_coef: 0.4989
# Epoch 9/20
# 395/395 [==============================] - 349s 883ms/step - loss: 0.5079 - dice_coef: 0.5316 - val_loss: 0.5951 - val_dice_coef: 0.4494
# Epoch 10/20
# 395/395 [==============================] - 348s 882ms/step - loss: 0.5063 - dice_coef: 0.5341 - val_loss: 0.7663 - val_dice_coef: 0.3142
# Epoch 11/20
# 395/395 [==============================] - 345s 875ms/step - loss: 0.5007 - dice_coef: 0.5383 - val_loss: 0.5567 - val_dice_coef: 0.4844
# Epoch 12/20
# 395/395 [==============================] - 348s 882ms/step - loss: 0.4913 - dice_coef: 0.5472 - val_loss: 0.5327 - val_dice_coef: 0.5053
# Epoch 13/20
# 395/395 [==============================] - 345s 873ms/step - loss: 0.4786 - dice_coef: 0.5586 - val_loss: 0.6040 - val_dice_coef: 0.4398
# Epoch 14/20
# 117/395 [=======>......................] - ETA: 3:57 - loss: 0.4969 - dice_coef: 0.5410

# %% [markdown]
# ### Save all histories

# %%
pd.DataFrame(unet_history.history).to_csv('./history/unet_history.csv')
pd.DataFrame(unet_res_history.history).to_csv('./history/unet_res_history.csv')
pd.DataFrame(unet_invres_history.history).to_csv('./history/unet_invres_history.csv')
