# %%
import os
import json
import gc
import cv2
import tensorflow as tf
from tensorflow.python.keras import backend as K
from tensorflow.python.keras import layers
from tensorflow.python.keras.preprocessing.image import ImageDataGenerator
from tensorflow.python.keras.models import Model, load_model
from tensorflow.python.keras.layers import concatenate, Input
from tensorflow.python.keras.layers import *
from tensorflow.python.keras.optimizers import Adam
from tensorflow.python.keras.callbacks import Callback, ModelCheckpoint
import matplotlib.pyplot as plt
from tensorflow.python.keras.utils import multi_gpu_model
import numpy as np
import pandas as pd
from tqdm import tqdm
os.environ["CUDA_VISIBLE_DEVICES"]="1"
# Out:
# /Users/nightshade/anaconda3/envs/testenv/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Users/nightshade/anaconda3/envs/testenv/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Users/nightshade/anaconda3/envs/testenv/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /Users/nightshade/anaconda3/envs/testenv/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /Users/nightshade/anaconda3/envs/testenv/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /Users/nightshade/anaconda3/envs/testenv/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /Users/nightshade/anaconda3/envs/testenv/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Users/nightshade/anaconda3/envs/testenv/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Users/nightshade/anaconda3/envs/testenv/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /Users/nightshade/anaconda3/envs/testenv/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /Users/nightshade/anaconda3/envs/testenv/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /Users/nightshade/anaconda3/envs/testenv/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %% [markdown]
# ## Preprocessing

# %%
train_df = pd.read_csv('../input/train.csv')
train_df = train_df.head(1000)
train_df['ImageId'] = train_df['ImageId_ClassId'].apply(lambda x: x.split('_')[0])
train_df['ClassId'] = train_df['ImageId_ClassId'].apply(lambda x: x.split('_')[1])
train_df['hasMask'] = ~ train_df['EncodedPixels'].isna()

# %%
mask_count_df = train_df.groupby('ImageId').agg(np.sum).reset_index()
mask_count_df.sort_values('hasMask', ascending=False, inplace=True)
non_missing_train_idx = mask_count_df[mask_count_df['hasMask'] > 0]

# %% [markdown]
# ## Utility Functions

# %%
def mask2rle(img):
    pixels= img.T.flatten()
    pixels = np.concatenate([[0], pixels, [0]])
    runs = np.where(pixels[1:] != pixels[:-1])[0] + 1
    runs[1::2] -= runs[::2]
    return ' '.join(str(x) for x in runs)

def rle2mask(rle, input_shape):
    width, height = input_shape[:2]
    
    mask= np.zeros( width*height ).astype(np.uint8)
    
    array = np.asarray([int(x) for x in rle.split()])
    starts = array[0::2]
    lengths = array[1::2]

    current_position = 0
    for index, start in enumerate(starts):
        mask[int(start):int(start+lengths[index])] = 1
        current_position += lengths[index]
        
    return mask.reshape(height, width).T

def build_masks(rles, input_shape):
    depth = len(rles)
    masks = np.zeros((*input_shape, depth))
    
    for i, rle in enumerate(rles):
        if type(rle) is str:
            masks[:, :, i] = rle2mask(rle, input_shape)
    
    return masks

def build_rles(masks):
    width, height, depth = masks.shape
    
    rles = [mask2rle(masks[:, :, i])
            for i in range(depth)]
    
    return rles

# %% [markdown]
# ## Data Generator

# %%
class DataGenerator(tf.keras.utils.Sequence):
    'Generates data for Keras'
    def __init__(self, list_IDs, df, target_df=None, mode='fit',
                 base_path='../input/train_images',
                 batch_size=32, dim=(256, 1600), n_channels=1,
                 n_classes=4, random_state=2019, shuffle=True):
        self.dim = dim
        self.batch_size = batch_size
        self.df = df
        self.mode = mode
        self.base_path = base_path
        self.target_df = target_df
        self.list_IDs = list_IDs
        self.n_channels = n_channels
        self.n_classes = n_classes
        self.shuffle = shuffle
        self.random_state = random_state
        
        self.on_epoch_end()

    def __len__(self):
        'Denotes the number of batches per epoch'
        return int(np.floor(len(self.list_IDs) / self.batch_size))

    def __getitem__(self, index):
        'Generate one batch of data'
        indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]

        # Find list of IDs
        list_IDs_batch = [self.list_IDs[k] for k in indexes]
        
        X = self.__generate_X(list_IDs_batch)
        
        if self.mode == 'fit':
            y = self.__generate_y(list_IDs_batch)
            return X, y
        
        elif self.mode == 'predict':
            return X

        else:
            raise AttributeError('The mode parameter should be set to "fit" or "predict".')
        
    def on_epoch_end(self):
        'Updates indexes after each epoch'
        self.indexes = np.arange(len(self.list_IDs))
        if self.shuffle == True:
            np.random.seed(self.random_state)
            np.random.shuffle(self.indexes)
    
    def __generate_X(self, list_IDs_batch):
        'Generates data containing batch_size samples'
        # Initialization
        X = np.empty((self.batch_size, *self.dim, self.n_channels))
        
        # Generate data
        for i, ID in enumerate(list_IDs_batch):
            im_name = self.df['ImageId'].iloc[ID]
            img_path = f"{self.base_path}/{im_name}"
            img = self.__load_grayscale(img_path)
            
            # Store samples
            X[i,] = img

        return X
    
    def __generate_y(self, list_IDs_batch):
        y = np.empty((self.batch_size, *self.dim, self.n_classes), dtype=int)
        
        for i, ID in enumerate(list_IDs_batch):
            im_name = self.df['ImageId'].iloc[ID]
            image_df = self.target_df[self.target_df['ImageId'] == im_name]
            
            rles = image_df['EncodedPixels'].values
            masks = build_masks(rles, input_shape=self.dim)
            
            y[i, ] = masks

        return y
    
    def __load_grayscale(self, img_path):
        img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
        img = img.astype(np.float32) / 255.
        img = np.expand_dims(img, axis=-1)

        return img

# %%
BATCH_SIZE = 16

train = np.array(non_missing_train_idx.index)

np.random.shuffle(train)
train_num = int(len(train)*0.95)
train_idx = train[:train_num]
val_idx = train[train_num:]

train_generator = DataGenerator(
    train_idx, 
    df=mask_count_df,
    target_df=train_df,
    batch_size=BATCH_SIZE, 
    n_classes=4
)

val_generator = DataGenerator(
    val_idx, 
    df=mask_count_df,
    target_df=train_df,
    batch_size=BATCH_SIZE, 
    n_classes=4
)

# %% [markdown]
# ## Model

# %%
def dice_coef(y_true, y_pred, smooth=1):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

# %%
def build_model(input_shape):
    num_classes = 4
    width = 8
    def conv_block(x, width, k_reg=False):
        c1 = Conv2D(width, (3, 3), activation='relu', padding='same') (x)
        c1 = Conv2D(width, (3, 3), activation='relu', padding='same') (c1)
        return c1

    inputs = Input(input_shape)
    activation = 'sigmoid'
    c1 = conv_block(inputs, width)
    p1 = MaxPooling2D((2, 2)) (c1)

    c2 = conv_block(p1, width*2, k_reg=True)
    p2 = MaxPooling2D((2, 2)) (c2)

    c3 = conv_block(p2, width*4, k_reg=True)
    p3 = MaxPooling2D((2, 2)) (c3)

    c4 = conv_block(p3, width*8, k_reg=True)
    p4 = MaxPooling2D(pool_size=(2, 2)) (c4)

    c5 = conv_block(p4, width*16)
    p5 = MaxPooling2D(pool_size=(2, 2)) (c5)
    
    cm = conv_block(p5, width*8)
    m1 = Conv2D(width*8, (3, 3), activation='relu', dilation_rate = 2, padding='same') (cm)
    m2 = Conv2D(width*8, (3, 3), activation='relu', dilation_rate = 4, padding='same') (m1)
    m3 = Conv2D(width*8, (3, 3), activation='relu', dilation_rate = 8, padding='same') (m2)
    m4 = Conv2D(width*8, (3, 3), activation='relu', dilation_rate = 16, padding='same') (m2)
    cm = concatenate([cm, m1, m2, m3, m4])
    
    um = Conv2DTranspose(width*16, (2, 2), strides=(2, 2), padding='same') (cm)
    um = concatenate([um, c5])
    cm = conv_block(um, width*16)

    u6 = Conv2DTranspose(width*8, (2, 2), strides=(2, 2), padding='same') (cm)
    u6 = concatenate([u6, c4])
    c6 = conv_block(u6, width*8)

    u7 = Conv2DTranspose(width*4, (2, 2), strides=(2, 2), padding='same') (c6)
    u7 = concatenate([u7, c3])
    c7 = conv_block(u7, width*4)

    u8 = Conv2DTranspose(width*2, (2, 2), strides=(2, 2), padding='same') (c7)
    u8 = concatenate([u8, c2])
    c8 = conv_block(u8, width*2)

    u9 = Conv2DTranspose(width, (2, 2), strides=(2, 2), padding='same') (c8)
    u9 = concatenate([u9, c1], axis=3)
    c9 = conv_block(u9, width)

    outputs = Conv2D(num_classes, (1, 1), activation=activation) (c9)
    model = Model(inputs=[inputs], outputs=[outputs])
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=[dice_coef])
    
    return model

# %%
# model = build_model((256, 1600, 1))
from model_deeplab import Deeplabv3
model = Deeplabv3(input_shape=(256, 1600, 1), classes=4)  
model.summary()
# Out:
# Model: "deeplabv3plus"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 256, 1600, 1 0
# __________________________________________________________________________________________________
# Conv (Conv2D)                   (None, 128, 800, 32) 288         input_2[0][0]
# __________________________________________________________________________________________________
# Conv_BN (BatchNormalizationV1)  (None, 128, 800, 32) 128         Conv[0][0]
# __________________________________________________________________________________________________
# Conv_Relu6 (Activation)         (None, 128, 800, 32) 0           Conv_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise (Depthw (None, 128, 800, 32) 288         Conv_Relu6[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_BN (Bat (None, 128, 800, 32) 128         expanded_conv_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_relu (A (None, 128, 800, 32) 0           expanded_conv_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_project (Conv2D)  (None, 128, 800, 16) 512         expanded_conv_depthwise_relu[0][0
# __________________________________________________________________________________________________
# expanded_conv_project_BN (Batch (None, 128, 800, 16) 64          expanded_conv_project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_1_expand (Conv2D) (None, 128, 800, 96) 1536        expanded_conv_project_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_1_expand_BN (Batc (None, 128, 800, 96) 384         expanded_conv_1_expand[0][0]
# __________________________________________________________________________________________________
# expanded_conv_1_expand_relu (Ac (None, 128, 800, 96) 0           expanded_conv_1_expand_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_1_depthwise (Dept (None, 64, 400, 96)  864         expanded_conv_1_expand_relu[0][0]
# __________________________________________________________________________________________________
# expanded_conv_1_depthwise_BN (B (None, 64, 400, 96)  384         expanded_conv_1_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_1_depthwise_relu  (None, 64, 400, 96)  0           expanded_conv_1_depthwise_BN[0][0
# __________________________________________________________________________________________________
# expanded_conv_1_project (Conv2D (None, 64, 400, 24)  2304        expanded_conv_1_depthwise_relu[0]
# __________________________________________________________________________________________________
# expanded_conv_1_project_BN (Bat (None, 64, 400, 24)  96          expanded_conv_1_project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_2_expand (Conv2D) (None, 64, 400, 144) 3456        expanded_conv_1_project_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_2_expand_BN (Batc (None, 64, 400, 144) 576         expanded_conv_2_expand[0][0]
# __________________________________________________________________________________________________
# expanded_conv_2_expand_relu (Ac (None, 64, 400, 144) 0           expanded_conv_2_expand_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_2_depthwise (Dept (None, 64, 400, 144) 1296        expanded_conv_2_expand_relu[0][0]
# __________________________________________________________________________________________________
# expanded_conv_2_depthwise_BN (B (None, 64, 400, 144) 576         expanded_conv_2_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_2_depthwise_relu  (None, 64, 400, 144) 0           expanded_conv_2_depthwise_BN[0][0
# __________________________________________________________________________________________________
# expanded_conv_2_project (Conv2D (None, 64, 400, 24)  3456        expanded_conv_2_depthwise_relu[0]
# __________________________________________________________________________________________________
# expanded_conv_2_project_BN (Bat (None, 64, 400, 24)  96          expanded_conv_2_project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_2_add (Add)       (None, 64, 400, 24)  0           expanded_conv_1_project_BN[0][0]
#                                                                  expanded_conv_2_project_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_3_expand (Conv2D) (None, 64, 400, 144) 3456        expanded_conv_2_add[0][0]
# __________________________________________________________________________________________________
# expanded_conv_3_expand_BN (Batc (None, 64, 400, 144) 576         expanded_conv_3_expand[0][0]
# __________________________________________________________________________________________________
# expanded_conv_3_expand_relu (Ac (None, 64, 400, 144) 0           expanded_conv_3_expand_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_3_depthwise (Dept (None, 32, 200, 144) 1296        expanded_conv_3_expand_relu[0][0]
# __________________________________________________________________________________________________
# expanded_conv_3_depthwise_BN (B (None, 32, 200, 144) 576         expanded_conv_3_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_3_depthwise_relu  (None, 32, 200, 144) 0           expanded_conv_3_depthwise_BN[0][0
# __________________________________________________________________________________________________
# expanded_conv_3_project (Conv2D (None, 32, 200, 32)  4608        expanded_conv_3_depthwise_relu[0]
# __________________________________________________________________________________________________
# expanded_conv_3_project_BN (Bat (None, 32, 200, 32)  128         expanded_conv_3_project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_4_expand (Conv2D) (None, 32, 200, 192) 6144        expanded_conv_3_project_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_4_expand_BN (Batc (None, 32, 200, 192) 768         expanded_conv_4_expand[0][0]
# __________________________________________________________________________________________________
# expanded_conv_4_expand_relu (Ac (None, 32, 200, 192) 0           expanded_conv_4_expand_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_4_depthwise (Dept (None, 32, 200, 192) 1728        expanded_conv_4_expand_relu[0][0]
# __________________________________________________________________________________________________
# expanded_conv_4_depthwise_BN (B (None, 32, 200, 192) 768         expanded_conv_4_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_4_depthwise_relu  (None, 32, 200, 192) 0           expanded_conv_4_depthwise_BN[0][0
# __________________________________________________________________________________________________
# expanded_conv_4_project (Conv2D (None, 32, 200, 32)  6144        expanded_conv_4_depthwise_relu[0]
# __________________________________________________________________________________________________
# expanded_conv_4_project_BN (Bat (None, 32, 200, 32)  128         expanded_conv_4_project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_4_add (Add)       (None, 32, 200, 32)  0           expanded_conv_3_project_BN[0][0]
#                                                                  expanded_conv_4_project_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_5_expand (Conv2D) (None, 32, 200, 192) 6144        expanded_conv_4_add[0][0]
# __________________________________________________________________________________________________
# expanded_conv_5_expand_BN (Batc (None, 32, 200, 192) 768         expanded_conv_5_expand[0][0]
# __________________________________________________________________________________________________
# expanded_conv_5_expand_relu (Ac (None, 32, 200, 192) 0           expanded_conv_5_expand_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_5_depthwise (Dept (None, 32, 200, 192) 1728        expanded_conv_5_expand_relu[0][0]
# __________________________________________________________________________________________________
# expanded_conv_5_depthwise_BN (B (None, 32, 200, 192) 768         expanded_conv_5_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_5_depthwise_relu  (None, 32, 200, 192) 0           expanded_conv_5_depthwise_BN[0][0
# __________________________________________________________________________________________________
# expanded_conv_5_project (Conv2D (None, 32, 200, 32)  6144        expanded_conv_5_depthwise_relu[0]
# __________________________________________________________________________________________________
# expanded_conv_5_project_BN (Bat (None, 32, 200, 32)  128         expanded_conv_5_project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_5_add (Add)       (None, 32, 200, 32)  0           expanded_conv_4_add[0][0]
#                                                                  expanded_conv_5_project_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_6_expand (Conv2D) (None, 32, 200, 192) 6144        expanded_conv_5_add[0][0]
# __________________________________________________________________________________________________
# expanded_conv_6_expand_BN (Batc (None, 32, 200, 192) 768         expanded_conv_6_expand[0][0]
# __________________________________________________________________________________________________
# expanded_conv_6_expand_relu (Ac (None, 32, 200, 192) 0           expanded_conv_6_expand_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_6_depthwise (Dept (None, 32, 200, 192) 1728        expanded_conv_6_expand_relu[0][0]
# __________________________________________________________________________________________________
# expanded_conv_6_depthwise_BN (B (None, 32, 200, 192) 768         expanded_conv_6_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_6_depthwise_relu  (None, 32, 200, 192) 0           expanded_conv_6_depthwise_BN[0][0
# __________________________________________________________________________________________________
# expanded_conv_6_project (Conv2D (None, 32, 200, 64)  12288       expanded_conv_6_depthwise_relu[0]
# __________________________________________________________________________________________________
# expanded_conv_6_project_BN (Bat (None, 32, 200, 64)  256         expanded_conv_6_project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_7_expand (Conv2D) (None, 32, 200, 384) 24576       expanded_conv_6_project_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_7_expand_BN (Batc (None, 32, 200, 384) 1536        expanded_conv_7_expand[0][0]
# __________________________________________________________________________________________________
# expanded_conv_7_expand_relu (Ac (None, 32, 200, 384) 0           expanded_conv_7_expand_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_7_depthwise (Dept (None, 32, 200, 384) 3456        expanded_conv_7_expand_relu[0][0]
# __________________________________________________________________________________________________
# expanded_conv_7_depthwise_BN (B (None, 32, 200, 384) 1536        expanded_conv_7_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_7_depthwise_relu  (None, 32, 200, 384) 0           expanded_conv_7_depthwise_BN[0][0
# __________________________________________________________________________________________________
# expanded_conv_7_project (Conv2D (None, 32, 200, 64)  24576       expanded_conv_7_depthwise_relu[0]
# __________________________________________________________________________________________________
# expanded_conv_7_project_BN (Bat (None, 32, 200, 64)  256         expanded_conv_7_project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_7_add (Add)       (None, 32, 200, 64)  0           expanded_conv_6_project_BN[0][0]
#                                                                  expanded_conv_7_project_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_8_expand (Conv2D) (None, 32, 200, 384) 24576       expanded_conv_7_add[0][0]
# __________________________________________________________________________________________________
# expanded_conv_8_expand_BN (Batc (None, 32, 200, 384) 1536        expanded_conv_8_expand[0][0]
# __________________________________________________________________________________________________
# expanded_conv_8_expand_relu (Ac (None, 32, 200, 384) 0           expanded_conv_8_expand_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_8_depthwise (Dept (None, 32, 200, 384) 3456        expanded_conv_8_expand_relu[0][0]
# __________________________________________________________________________________________________
# expanded_conv_8_depthwise_BN (B (None, 32, 200, 384) 1536        expanded_conv_8_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_8_depthwise_relu  (None, 32, 200, 384) 0           expanded_conv_8_depthwise_BN[0][0
# __________________________________________________________________________________________________
# expanded_conv_8_project (Conv2D (None, 32, 200, 64)  24576       expanded_conv_8_depthwise_relu[0]
# __________________________________________________________________________________________________
# expanded_conv_8_project_BN (Bat (None, 32, 200, 64)  256         expanded_conv_8_project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_8_add (Add)       (None, 32, 200, 64)  0           expanded_conv_7_add[0][0]
#                                                                  expanded_conv_8_project_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_9_expand (Conv2D) (None, 32, 200, 384) 24576       expanded_conv_8_add[0][0]
# __________________________________________________________________________________________________
# expanded_conv_9_expand_BN (Batc (None, 32, 200, 384) 1536        expanded_conv_9_expand[0][0]
# __________________________________________________________________________________________________
# expanded_conv_9_expand_relu (Ac (None, 32, 200, 384) 0           expanded_conv_9_expand_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_9_depthwise (Dept (None, 32, 200, 384) 3456        expanded_conv_9_expand_relu[0][0]
# __________________________________________________________________________________________________
# expanded_conv_9_depthwise_BN (B (None, 32, 200, 384) 1536        expanded_conv_9_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_9_depthwise_relu  (None, 32, 200, 384) 0           expanded_conv_9_depthwise_BN[0][0
# __________________________________________________________________________________________________
# expanded_conv_9_project (Conv2D (None, 32, 200, 64)  24576       expanded_conv_9_depthwise_relu[0]
# __________________________________________________________________________________________________
# expanded_conv_9_project_BN (Bat (None, 32, 200, 64)  256         expanded_conv_9_project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_9_add (Add)       (None, 32, 200, 64)  0           expanded_conv_8_add[0][0]
#                                                                  expanded_conv_9_project_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_10_expand (Conv2D (None, 32, 200, 384) 24576       expanded_conv_9_add[0][0]
# __________________________________________________________________________________________________
# expanded_conv_10_expand_BN (Bat (None, 32, 200, 384) 1536        expanded_conv_10_expand[0][0]
# __________________________________________________________________________________________________
# expanded_conv_10_expand_relu (A (None, 32, 200, 384) 0           expanded_conv_10_expand_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_10_depthwise (Dep (None, 32, 200, 384) 3456        expanded_conv_10_expand_relu[0][0
# __________________________________________________________________________________________________
# expanded_conv_10_depthwise_BN ( (None, 32, 200, 384) 1536        expanded_conv_10_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_10_depthwise_relu (None, 32, 200, 384) 0           expanded_conv_10_depthwise_BN[0][
# __________________________________________________________________________________________________
# expanded_conv_10_project (Conv2 (None, 32, 200, 96)  36864       expanded_conv_10_depthwise_relu[0
# __________________________________________________________________________________________________
# expanded_conv_10_project_BN (Ba (None, 32, 200, 96)  384         expanded_conv_10_project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_11_expand (Conv2D (None, 32, 200, 576) 55296       expanded_conv_10_project_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_11_expand_BN (Bat (None, 32, 200, 576) 2304        expanded_conv_11_expand[0][0]
# __________________________________________________________________________________________________
# expanded_conv_11_expand_relu (A (None, 32, 200, 576) 0           expanded_conv_11_expand_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_11_depthwise (Dep (None, 32, 200, 576) 5184        expanded_conv_11_expand_relu[0][0
# __________________________________________________________________________________________________
# expanded_conv_11_depthwise_BN ( (None, 32, 200, 576) 2304        expanded_conv_11_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_11_depthwise_relu (None, 32, 200, 576) 0           expanded_conv_11_depthwise_BN[0][
# __________________________________________________________________________________________________
# expanded_conv_11_project (Conv2 (None, 32, 200, 96)  55296       expanded_conv_11_depthwise_relu[0
# __________________________________________________________________________________________________
# expanded_conv_11_project_BN (Ba (None, 32, 200, 96)  384         expanded_conv_11_project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_11_add (Add)      (None, 32, 200, 96)  0           expanded_conv_10_project_BN[0][0]
#                                                                  expanded_conv_11_project_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_12_expand (Conv2D (None, 32, 200, 576) 55296       expanded_conv_11_add[0][0]
# __________________________________________________________________________________________________
# expanded_conv_12_expand_BN (Bat (None, 32, 200, 576) 2304        expanded_conv_12_expand[0][0]
# __________________________________________________________________________________________________
# expanded_conv_12_expand_relu (A (None, 32, 200, 576) 0           expanded_conv_12_expand_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_12_depthwise (Dep (None, 32, 200, 576) 5184        expanded_conv_12_expand_relu[0][0
# __________________________________________________________________________________________________
# expanded_conv_12_depthwise_BN ( (None, 32, 200, 576) 2304        expanded_conv_12_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_12_depthwise_relu (None, 32, 200, 576) 0           expanded_conv_12_depthwise_BN[0][
# __________________________________________________________________________________________________
# expanded_conv_12_project (Conv2 (None, 32, 200, 96)  55296       expanded_conv_12_depthwise_relu[0
# __________________________________________________________________________________________________
# expanded_conv_12_project_BN (Ba (None, 32, 200, 96)  384         expanded_conv_12_project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_12_add (Add)      (None, 32, 200, 96)  0           expanded_conv_11_add[0][0]
#                                                                  expanded_conv_12_project_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_13_expand (Conv2D (None, 32, 200, 576) 55296       expanded_conv_12_add[0][0]
# __________________________________________________________________________________________________
# expanded_conv_13_expand_BN (Bat (None, 32, 200, 576) 2304        expanded_conv_13_expand[0][0]
# __________________________________________________________________________________________________
# expanded_conv_13_expand_relu (A (None, 32, 200, 576) 0           expanded_conv_13_expand_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_13_depthwise (Dep (None, 32, 200, 576) 5184        expanded_conv_13_expand_relu[0][0
# __________________________________________________________________________________________________
# expanded_conv_13_depthwise_BN ( (None, 32, 200, 576) 2304        expanded_conv_13_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_13_depthwise_relu (None, 32, 200, 576) 0           expanded_conv_13_depthwise_BN[0][
# __________________________________________________________________________________________________
# expanded_conv_13_project (Conv2 (None, 32, 200, 160) 92160       expanded_conv_13_depthwise_relu[0
# __________________________________________________________________________________________________
# expanded_conv_13_project_BN (Ba (None, 32, 200, 160) 640         expanded_conv_13_project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_14_expand (Conv2D (None, 32, 200, 960) 153600      expanded_conv_13_project_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_14_expand_BN (Bat (None, 32, 200, 960) 3840        expanded_conv_14_expand[0][0]
# __________________________________________________________________________________________________
# expanded_conv_14_expand_relu (A (None, 32, 200, 960) 0           expanded_conv_14_expand_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_14_depthwise (Dep (None, 32, 200, 960) 8640        expanded_conv_14_expand_relu[0][0
# __________________________________________________________________________________________________
# expanded_conv_14_depthwise_BN ( (None, 32, 200, 960) 3840        expanded_conv_14_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_14_depthwise_relu (None, 32, 200, 960) 0           expanded_conv_14_depthwise_BN[0][
# __________________________________________________________________________________________________
# expanded_conv_14_project (Conv2 (None, 32, 200, 160) 153600      expanded_conv_14_depthwise_relu[0
# __________________________________________________________________________________________________
# expanded_conv_14_project_BN (Ba (None, 32, 200, 160) 640         expanded_conv_14_project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_14_add (Add)      (None, 32, 200, 160) 0           expanded_conv_13_project_BN[0][0]
#                                                                  expanded_conv_14_project_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_15_expand (Conv2D (None, 32, 200, 960) 153600      expanded_conv_14_add[0][0]
# __________________________________________________________________________________________________
# expanded_conv_15_expand_BN (Bat (None, 32, 200, 960) 3840        expanded_conv_15_expand[0][0]
# __________________________________________________________________________________________________
# expanded_conv_15_expand_relu (A (None, 32, 200, 960) 0           expanded_conv_15_expand_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_15_depthwise (Dep (None, 32, 200, 960) 8640        expanded_conv_15_expand_relu[0][0
# __________________________________________________________________________________________________
# expanded_conv_15_depthwise_BN ( (None, 32, 200, 960) 3840        expanded_conv_15_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_15_depthwise_relu (None, 32, 200, 960) 0           expanded_conv_15_depthwise_BN[0][
# __________________________________________________________________________________________________
# expanded_conv_15_project (Conv2 (None, 32, 200, 160) 153600      expanded_conv_15_depthwise_relu[0
# __________________________________________________________________________________________________
# expanded_conv_15_project_BN (Ba (None, 32, 200, 160) 640         expanded_conv_15_project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_15_add (Add)      (None, 32, 200, 160) 0           expanded_conv_14_add[0][0]
#                                                                  expanded_conv_15_project_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_16_expand (Conv2D (None, 32, 200, 960) 153600      expanded_conv_15_add[0][0]
# __________________________________________________________________________________________________
# expanded_conv_16_expand_BN (Bat (None, 32, 200, 960) 3840        expanded_conv_16_expand[0][0]
# __________________________________________________________________________________________________
# expanded_conv_16_expand_relu (A (None, 32, 200, 960) 0           expanded_conv_16_expand_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_16_depthwise (Dep (None, 32, 200, 960) 8640        expanded_conv_16_expand_relu[0][0
# __________________________________________________________________________________________________
# expanded_conv_16_depthwise_BN ( (None, 32, 200, 960) 3840        expanded_conv_16_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_16_depthwise_relu (None, 32, 200, 960) 0           expanded_conv_16_depthwise_BN[0][
# __________________________________________________________________________________________________
# expanded_conv_16_project (Conv2 (None, 32, 200, 320) 307200      expanded_conv_16_depthwise_relu[0
# __________________________________________________________________________________________________
# expanded_conv_16_project_BN (Ba (None, 32, 200, 320) 1280        expanded_conv_16_project[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 320)          0           expanded_conv_16_project_BN[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 1, 320)       0           global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 1, 1, 320)    0           lambda_4[0][0]
# __________________________________________________________________________________________________
# image_pooling (Conv2D)          (None, 1, 1, 256)    81920       lambda_5[0][0]
# __________________________________________________________________________________________________
# image_pooling_BN (BatchNormaliz (None, 1, 1, 256)    1024        image_pooling[0][0]
# __________________________________________________________________________________________________
# aspp0 (Conv2D)                  (None, 32, 200, 256) 81920       expanded_conv_16_project_BN[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 1, 1, 256)    0           image_pooling_BN[0][0]
# __________________________________________________________________________________________________
# aspp0_BN (BatchNormalizationV1) (None, 32, 200, 256) 1024        aspp0[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 32, 200, 256) 0           activation_2[0][0]
# __________________________________________________________________________________________________
# aspp0_activation (Activation)   (None, 32, 200, 256) 0           aspp0_BN[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 32, 200, 512) 0           lambda_6[0][0]
#                                                                  aspp0_activation[0][0]
# __________________________________________________________________________________________________
# concat_projection (Conv2D)      (None, 32, 200, 256) 131072      concatenate_1[0][0]
# __________________________________________________________________________________________________
# concat_projection_BN (BatchNorm (None, 32, 200, 256) 1024        concat_projection[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 32, 200, 256) 0           concat_projection_BN[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 32, 200, 256) 0           activation_3[0][0]
# __________________________________________________________________________________________________
# custom_logits_semantic (Conv2D) (None, 32, 200, 4)   1028        dropout_1[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 256, 1600, 4) 0           custom_logits_semantic[0][0]
# ==================================================================================================
# Total params: 2,141,700
# Trainable params: 2,108,612
# Non-trainable params: 33,088
# __________________________________________________________________________________________________

# %%
#/model = multi_gpu_model(model, gpus=4)
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=[dice_coef])

# %%
checkpoint = ModelCheckpoint(
    'base_UNET_MCAD.h5', 
    monitor='val_dice_coef', 
    verbose=0, 
    save_best_only=True, 
    save_weights_only=False,
    mode='auto'
)

history = model.fit_generator(
    train_generator,
    validation_data=val_generator,
    callbacks=[checkpoint],
    use_multiprocessing=False,
    workers=1,
    epochs=20
)

# %% [markdown]
# # if the model learns, then add function for context module

# %% [markdown]
# ## Evaluation

# %%
history_df = pd.DataFrame(history.history)
history_df[['loss', 'val_loss']].plot()
history_df[['dice_coef', 'val_dice_coef']].plot()

# %%
history_df.to_csv('history/base_UNET_MCAD_history.csv')

# %% [markdown]
# ## Visualize

# %%
test = val_generator.__getitem__(6)
print(len(test), test[0].shape, test[1].shape)
plt.imshow(np.squeeze(test[0][0])); plt.show()
plt.imshow(test[1][0][...,0]); plt.show()
plt.imshow(test[1][0][...,1]); plt.show()
plt.imshow(test[1][0][...,2]); plt.show()
plt.imshow(test[1][0][...,3])

# %%
test_pred = np.squeeze(model.predict(np.expand_dims(test[0][0], axis=0)))
plt.imshow(np.squeeze(test_pred)[...,0]); plt.show()
plt.imshow(np.squeeze(test_pred)[...,1]); plt.show()
plt.imshow(np.squeeze(test_pred)[...,2]); plt.show()
plt.imshow(np.squeeze(test_pred)[...,3])

# %%
def load_img(code, base, resize=True):
    path = f'{base}/{code}'
    img = cv2.imread(path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    if resize:
        img = cv2.resize(img, (256, 256))
    
    return img

def validate_path(path):
    if not os.path.exists(path):
        os.makedirs(path)

# %%
BATCH_SIZE = 64
model = load_model('base_UNET_MCAD.h5', custom_objects={'dice_coef': dice_coef})
sub_df = pd.read_csv('../input/sample_submission.csv')
sub_df['ImageId'] = sub_df['ImageId_ClassId'].apply(lambda x: x.split('_')[0])
test_imgs = pd.DataFrame(sub_df['ImageId'].unique(), columns=['ImageId'])
test_imgs.head()

# %%
test_generator = DataGenerator(test_imgs.index, df=test_imgs, shuffle=False, mode='predict', target_df=test_imgs,
        base_path='../input/test_images',
        batch_size=BATCH_SIZE,
        n_classes=4
    )
test_df = []

for i in range(0, test_imgs.shape[0], 300):
    batch_idx = list(
        range(i, min(test_imgs.shape[0], i + 300))
    )
    
    test_generator = DataGenerator(batch_idx, df=test_imgs, shuffle=False,mode='predict',base_path='../input/test_images',
        target_df=sub_df,
        batch_size=1,
        n_classes=4
    )
    
    batch_pred_masks = model.predict_generator(
        test_generator, 
        workers=1,
        verbose=1,
        use_multiprocessing=False
    )
    
    for j, b in tqdm(enumerate(batch_idx)):
        filename = test_imgs['ImageId'].iloc[b]
        image_df = sub_df[sub_df['ImageId'] == filename].copy()
        
        pred_masks = batch_pred_masks[j, ].round().astype(int)
        pred_rles = build_rles(pred_masks)
        
        image_df['EncodedPixels'] = pred_rles
        test_df.append(image_df)
    gc.collect()

# %%
test_df = pd.concat(test_df)
print(test_df.shape)
test_df.head()

# %%
test_df[['ImageId_ClassId', 'EncodedPixels']].to_csv('submission.csv', index=False)
